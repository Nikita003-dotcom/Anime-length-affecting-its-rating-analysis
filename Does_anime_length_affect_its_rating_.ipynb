# %%
import pandas as pd

data = {
  'Title': [
    'Classroom of the Elite',
    'Death Note',
    'Code Geass',
    'Eminence in Shadow',
    'Solo Leveling',
    'Naruto (Classic + Shippuden)',
    'Jujutsu Kaisen (S1–S2)',
    'Darling in the FRANXX',
    'Demon Slayer',
    'Attack on Titan (first 3 seasons)'
  ],

  'Genres': [
    'Psychological thriller',
    'Psychological thriller',
    'Action,Drama,Sci-Fi',
    'Action-comedy, dark fantasy isekai',
    'Action-fantasy',
    'Action-adventure and fantasy',
    'Dark fantasy, supernatural adventure',
    'Mecha, sci-fi, romantic drama',
    'Dark fantasy, action-adventure',
    'Dark fantasy, post-apocalyptic action-thriller'
  ],

  'Rating': [
    9.36, 9.4, 9.6, 9.45, 9.6, 9.35, 9.35, 9.6, 9.5, 9.53
  ],

  'Episodes': [
    '12, 13, 13',
    '37',
    '25, 25',
    '20, 12',
    '12, 13',
    '220, 500',
    '24, 23',
    '24',
    '26, 11, 11, 8',
    '25, 12, 22'
  ],


  'Episode Length': [
    '24 min.', '23 min.', '24 min.', '24 min.', '24 min.',
    '24 min.', '24 min.', '24 min.', '24 min.', '24 min.'
  ],

  'Release Date': [
    'Summer 2017', 'Autumn 2006', 'Autumn 2006', 'Autumn 2022',
    'Spring 2024', 'Autumn 2002', 'Autumn 2020', 'Winter 2018',
    'Spring 2019', 'Spring 2013'
  ]
}

df = pd.DataFrame(data)




def count_total_eps(ep_string):
    nums = [int(x.strip()) for x in ep_string.split(',')]
    return sum(nums)

df["Total Episodes"] = df["Episodes"].apply(count_total_eps)


print(df)
# Out:
#                                Title  \
# 0             Classroom of the Elite
# 1                         Death Note
# 2                         Code Geass
# 3                 Eminence in Shadow
# 4                      Solo Leveling
# 5       Naruto (Classic + Shippuden)
# 6             Jujutsu Kaisen (S1–S2)
# 7              Darling in the FRANXX
# 8                       Demon Slayer
# 9  Attack on Titan (first 3 seasons)
#
#                                            Genres  Rating       Episodes  \
# 0                          Psychological thriller    9.36     12, 13, 13
# 1                          Psychological thriller    9.40             37
# 2                             Action,Drama,Sci-Fi    9.60         25, 25
# 3              Action-comedy, dark fantasy isekai    9.45         20, 12
# 4                                  Action-fantasy    9.60         12, 13
# 5                    Action-adventure and fantasy    9.35       220, 500
# 6            Dark fantasy, supernatural adventure    9.35         24, 23
# 7                   Mecha, sci-fi, romantic drama    9.60             24
# 8                  Dark fantasy, action-adventure    9.50  26, 11, 11, 8
# 9  Dark fantasy, post-apocalyptic action-thriller    9.53     25, 12, 22
#
#   Episode Length Release Date  Total Episodes
# 0        24 min.  Summer 2017              38
# 1        23 min.  Autumn 2006              37
# 2        24 min.  Autumn 2006              50
# 3        24 min.  Autumn 2022              32
# 4        24 min.  Spring 2024              25
# 5        24 min.  Autumn 2002             720
# 6        24 min.  Autumn 2020              47
# 7        24 min.  Winter 2018              24
# 8        24 min.  Spring 2019              56
# 9        24 min.  Spring 2013              59

# %%
df
# Out:
#                                Title  \
# 0             Classroom of the Elite
# 1                         Death Note
# 2                         Code Geass
# 3                 Eminence in Shadow
# 4                      Solo Leveling
# 5       Naruto (Classic + Shippuden)
# 6             Jujutsu Kaisen (S1–S2)
# 7              Darling in the FRANXX
# 8                       Demon Slayer
# 9  Attack on Titan (first 3 seasons)
#
#                                            Genres  Rating       Episodes  \
# 0                          Psychological thriller    9.36     12, 13, 13
# 1                          Psychological thriller    9.40             37
# 2                             Action,Drama,Sci-Fi    9.60         25, 25
# 3              Action-comedy, dark fantasy isekai    9.45         20, 12
# 4                                  Action-fantasy    9.60         12, 13
# 5                    Action-adventure and fantasy    9.35       220, 500
# 6            Dark fantasy, supernatural adventure    9.35         24, 23
# 7                   Mecha, sci-fi, romantic drama    9.60             24
# 8                  Dark fantasy, action-adventure    9.50  26, 11, 11, 8
# 9  Dark fantasy, post-apocalyptic action-thriller    9.53     25, 12, 22
#
#   Episode Length Release Date  Total Episodes
# 0        24 min.  Summer 2017              38
# 1        23 min.  Autumn 2006              37
# 2        24 min.  Autumn 2006              50
# 3        24 min.  Autumn 2022              32
# 4        24 min.  Spring 2024              25
# 5        24 min.  Autumn 2002             720
# 6        24 min.  Autumn 2020              47
# 7        24 min.  Winter 2018              24
# 8        24 min.  Spring 2019              56
# 9        24 min.  Spring 2013              59

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")  # cleaner look ig



#


plt.figure(figsize=(10,6))

sns.barplot(
    data=df.sort_values("Total Episodes", ascending=False),
    x="Total Episodes",
    y="Title",
    palette="viridis"
)

plt.title("Total Episodes per Anime")
plt.xlabel("Total Episodes")
plt.ylabel("Anime")

plt.tight_layout()
plt.show()




#


plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x="Total Episodes",
    y="Rating",
    s=150
)


sns.regplot(
    data=df,
    x="Total Episodes",
    y="Rating",
    scatter=False,
    color="red"
)

plt.title("Does Anime Length Affect Rating?")
plt.xlabel("Total Episodes")
plt.ylabel("Rating")

plt.tight_layout()
plt.show()


# correlation number
corr = df["Total Episodes"].corr(df["Rating"])
print(f"\nCorrelation between length and rating: {corr:.2f}")




#


plt.figure(figsize=(10,6))

sns.barplot(
    data=df.sort_values("Rating", ascending=False),
    x="Rating",
    y="Title",
    palette="magma"
)

plt.title("Anime Ranked by Rating")
plt.xlabel("Rating")
plt.ylabel("Anime")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2767119720.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Correlation between length and rating: -0.42
# /tmp/ipython-input-2767119720.py:71: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
